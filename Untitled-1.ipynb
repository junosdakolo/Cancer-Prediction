# %%
import os
import pandas as pd 
import numpy as np 
import matplotlib.pylab as plt 
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

os.chdir("C:\\Users\\junos\\OneDrive\\Documents\\PythonScripts")

print(os.getcwd())
# Out:
# C:\Users\junos\OneDrive\Documents\PythonScripts

# %%
# Data augmentation and preprocessing
datagen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2
)

train_data = datagen.flow_from_directory(
    r'C:\Users\junos\OneDrive\Documents\PythonScripts\dataset\Training',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

val_data = datagen.flow_from_directory(
    r'C:\Users\junos\OneDrive\Documents\PythonScripts\dataset\Validation',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 68 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
# Out:
# c:\Users\junos\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=25
)
# Out:
# Epoch 1/25
# c:\Users\junos\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 819ms/step - accuracy: 0.4706 - loss: 0.9908 - val_accuracy: 0.8000 - val_loss: 0.6262
# Epoch 2/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 537ms/step - accuracy: 0.4093 - loss: 0.7181 - val_accuracy: 0.3250 - val_loss: 0.7059
# Epoch 3/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 471ms/step - accuracy: 0.4857 - loss: 0.6748 - val_accuracy: 0.2000 - val_loss: 0.7338
# Epoch 4/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 495ms/step - accuracy: 0.6205 - loss: 0.6468 - val_accuracy: 0.7250 - val_loss: 0.6661
# Epoch 5/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - accuracy: 0.5733 - loss: 0.7098 - val_accuracy: 0.4250 - val_loss: 0.7405
# Epoch 6/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - accuracy: 0.7063 - loss: 0.6393 - val_accuracy: 0.6500 - val_loss: 0.6788
# Epoch 7/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 349ms/step - accuracy: 0.6854 - loss: 0.6176 - val_accuracy: 0.8000 - val_loss: 0.5758
# Epoch 8/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 451ms/step - accuracy: 0.4375 - loss: 0.7991 - val_accuracy: 0.7500 - val_loss: 0.6608
# Epoch 9/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - accuracy: 0.5416 - loss: 0.6905 - val_accuracy: 0.2000 - val_loss: 0.7650
# Epoch 10/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - accuracy: 0.5264 - loss: 0.6711 - val_accuracy: 0.2750 - val_loss: 0.7650
# Epoch 11/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 467ms/step - accuracy: 0.6344 - loss: 0.6371 - val_accuracy: 0.3000 - val_loss: 0.8389
# Epoch 12/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step - accuracy: 0.5949 - loss: 0.6221 - val_accuracy: 0.4750 - val_loss: 0.7606
# Epoch 13/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step - accuracy: 0.6595 - loss: 0.6191 - val_accuracy: 0.6250 - val_loss: 0.7303
# Epoch 14/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 461ms/step - accuracy: 0.8272 - loss: 0.5621 - val_accuracy: 0.6500 - val_loss: 0.7198
# Epoch 15/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 466ms/step - accuracy: 0.5572 - loss: 0.7553 - val_accuracy: 0.7500 - val_loss: 0.5946
# Epoch 16/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step - accuracy: 0.6474 - loss: 0.6657 - val_accuracy: 0.5500 - val_loss: 0.8572
# Epoch 17/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 508ms/step - accuracy: 0.7006 - loss: 0.5632 - val_accuracy: 0.7500 - val_loss: 0.7612
# Epoch 18/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 421ms/step - accuracy: 0.6928 - loss: 0.6022 - val_accuracy: 0.8000 - val_loss: 0.6990
# Epoch 19/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 430ms/step - accuracy: 0.6712 - loss: 0.6202 - val_accuracy: 0.4250 - val_loss: 0.8489
# Epoch 20/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 401ms/step - accuracy: 0.6322 - loss: 0.6118 - val_accuracy: 0.3000 - val_loss: 1.2891
# Epoch 21/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 422ms/step - accuracy: 0.6287 - loss: 0.5974 - val_accuracy: 0.6250 - val_loss: 0.8405
# Epoch 22/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 453ms/step - accuracy: 0.7534 - loss: 0.5728 - val_accuracy: 0.8000 - val_loss: 0.7203
# Epoch 23/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 0.6742 - loss: 0.6395 - val_accuracy: 0.7500 - val_loss: 0.6977
# Epoch 24/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 390ms/step - accuracy: 0.6893 - loss: 0.6177 - val_accuracy: 0.8000 - val_loss: 0.7629
# Epoch 25/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 576ms/step - accuracy: 0.7092 - loss: 0.5660 - val_accuracy: 0.5000 - val_loss: 1.3546

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Path to the test directory
test_dir = r'C:\Users\junos\OneDrive\Documents\PythonScripts\dataset\Test'

# Preprocessing for test data
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load test data
test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_data)
print(f"Test Accuracy: {test_acc}")
# Out:
# Found 18 images belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8889 - loss: 0.4299
# Test Accuracy: 0.8888888955116272

# %%
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np

# Generate predictions on test data
y_pred = np.round(model.predict(test_data))

# True labels
y_true = test_data.classes

# Print classification report
print(classification_report(y_true, y_pred, target_names=test_data.class_indices.keys()))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
#                precision    recall  f1-score   support
#
#     Cancerous       0.22      0.22      0.22         9
# Non-Cancerous       0.22      0.22      0.22         9
#
#      accuracy                           0.22        18
#     macro avg       0.22      0.22      0.22        18
#  weighted avg       0.22      0.22      0.22        18

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Paths to your dataset
base_dir = r'C:\Users\junos\OneDrive\Documents\PythonScripts\dataset'

# Data augmentation and preprocessing
datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    validation_split=0.2,  # Reserve 20% of data for validation
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2
)

# Load training and validation data
train_data = datagen.flow_from_directory(
    os.path.join(base_dir, 'Training'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

val_data = datagen.flow_from_directory(
    os.path.join(base_dir, 'Training'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

# Test data (no augmentation, only rescaling)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_data = test_datagen.flow_from_directory(
    os.path.join(base_dir, 'Test'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 54 images belonging to 2 classes.
# Found 12 images belonging to 2 classes.
# Found 18 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Binary classification output
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Print model summary
model.summary()
# Out:
# c:\Users\junos\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,169,089 (42.61 MB)
#  Trainable params: 11,169,089 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=25
)
# Out:
# Epoch 1/25
# c:\Users\junos\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 624ms/step - accuracy: 0.5331 - loss: 3.4730 - val_accuracy: 0.5000 - val_loss: 1.2236
# Epoch 2/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - accuracy: 0.5000 - loss: 1.0072 - val_accuracy: 0.5000 - val_loss: 0.7937
# Epoch 3/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 405ms/step - accuracy: 0.4877 - loss: 0.7596 - val_accuracy: 0.5833 - val_loss: 0.6896
# Epoch 4/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - accuracy: 0.5398 - loss: 0.6962 - val_accuracy: 0.5000 - val_loss: 0.7083
# Epoch 5/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 404ms/step - accuracy: 0.5426 - loss: 0.7054 - val_accuracy: 0.5000 - val_loss: 0.6982
# Epoch 6/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 407ms/step - accuracy: 0.6195 - loss: 0.6806 - val_accuracy: 0.5000 - val_loss: 0.6892
# Epoch 7/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.5000 - loss: 0.6868 - val_accuracy: 0.5000 - val_loss: 0.6872
# Epoch 8/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 422ms/step - accuracy: 0.5095 - loss: 0.6772 - val_accuracy: 0.5833 - val_loss: 0.6858
# Epoch 9/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 400ms/step - accuracy: 0.6992 - loss: 0.6436 - val_accuracy: 0.4167 - val_loss: 0.6878
# Epoch 10/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.5930 - loss: 0.6673 - val_accuracy: 0.5000 - val_loss: 0.7228
# Epoch 11/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.5664 - loss: 0.6859 - val_accuracy: 0.7500 - val_loss: 0.6681
# Epoch 12/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step - accuracy: 0.4545 - loss: 0.7022 - val_accuracy: 0.5000 - val_loss: 0.6773
# Epoch 13/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - accuracy: 0.5948 - loss: 0.7059 - val_accuracy: 0.5000 - val_loss: 0.6764
# Epoch 14/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 402ms/step - accuracy: 0.6044 - loss: 0.6849 - val_accuracy: 0.6667 - val_loss: 0.6612
# Epoch 15/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.6034 - loss: 0.6528 - val_accuracy: 0.5000 - val_loss: 0.6868
# Epoch 16/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 401ms/step - accuracy: 0.5426 - loss: 0.6616 - val_accuracy: 0.5833 - val_loss: 0.6674
# Epoch 17/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 426ms/step - accuracy: 0.6622 - loss: 0.5921 - val_accuracy: 0.6667 - val_loss: 0.6627
# Epoch 18/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step - accuracy: 0.6442 - loss: 0.6240 - val_accuracy: 0.6667 - val_loss: 0.6140
# Epoch 19/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 0.6821 - loss: 0.5889 - val_accuracy: 0.6667 - val_loss: 0.6015
# Epoch 20/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step - accuracy: 0.5494 - loss: 0.6193 - val_accuracy: 0.6667 - val_loss: 0.5940
# Epoch 21/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 0.5370 - loss: 0.6458 - val_accuracy: 0.7500 - val_loss: 0.5768
# Epoch 22/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 439ms/step - accuracy: 0.6689 - loss: 0.5969 - val_accuracy: 0.7500 - val_loss: 0.5793
# Epoch 23/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.7562 - loss: 0.5471 - val_accuracy: 0.7500 - val_loss: 0.5717
# Epoch 24/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step - accuracy: 0.7363 - loss: 0.5727 - val_accuracy: 0.7500 - val_loss: 0.4900
# Epoch 25/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 0.8140 - loss: 0.4622 - val_accuracy: 0.6667 - val_loss: 0.5168

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(test_data)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_acc}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7778 - loss: 0.3757
# Test Loss: 0.37568411231040955
# Test Accuracy: 0.7777777910232544

# %%
# Save the model
model.save('binary_classification_model.keras')

# Load the model (when needed)
from tensorflow.keras.models import load_model
loaded_model = load_model('binary_classification_model.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Save the model
# ----> 2 model.save('binary_classification_model.keras')
#       4 # Load the model (when needed)
#       5 from tensorflow.keras.models import load_model
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np

# Get predictions on the test dataset
test_data.reset()  # Ensure test data generator is reset before predictions
y_pred = np.round(loaded_model.predict(test_data))  # Predict classes
y_true = test_data.classes  # True labels

# Classification report
print(classification_report(y_true, y_pred, target_names=test_data.class_indices.keys()))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#                precision    recall  f1-score   support
#
#     Cancerous       0.67      0.67      0.67         9
# Non-Cancerous       0.67      0.67      0.67         9
#
#      accuracy                           0.67        18
#     macro avg       0.67      0.67      0.67        18
#  weighted avg       0.67      0.67      0.67        18
